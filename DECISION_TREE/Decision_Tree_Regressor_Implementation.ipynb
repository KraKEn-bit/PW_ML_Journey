# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import fetch_california_housing

# %%
data = fetch_california_housing()

# %%
print(data)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df['price'] = data.target

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  price
# ...

# %%
df.shape
# Out:
# (20640, 9)

# %%
df.sample(4)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 7073   3.4886      35.0  5.332481   1.023018      1112.0  2.843990     33.95
# 11754  6.5322      14.0  8.079681   1.015936       781.0  3.111554     38.76
# 18392  7.5845      25.0  7.119342   0.930041       721.0  2.967078     37.27
# 3912   3.1106      18.0  4.579688   1.032812      3161.0  2.469531     34.19
#
#        Longitude  price
# 7073     -118.02  1.739
# 11754    -121.17  3.940
# 18392    -121.87  2.793
# 3912     -118.55  1.706

# %% [markdown]
# ###**To Visualize the tree Selecting only 20% of the Data!**

# %%
df = df.sample(frac=0.2)

# %%
df.shape
# Out:
# (4128, 9)

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x
# Out:
#         MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 11520  15.0001      14.0  8.354232   1.037618       964.0  3.021944     33.72
# 7066    3.4792      34.0  4.624339   1.021164       917.0  2.425926     33.94
# 12346   2.5212      21.0  5.897924   1.335063      3623.0  2.089389     33.82
# 10186   4.4784      35.0  4.866142   1.005249      1115.0  2.926509     33.87
# 8449    2.7813      19.0  3.913655   1.122490      1282.0  2.574297     33.91
# ...        ...       ...       ...        ...         ...       ...       ...
# 6928    2.9107      35.0  3.578313   1.030120      1373.0  4.135542     34.00
# 2815    2.3250      35.0  5.171429   1.061538      1368.0  3.006593     35.42
# 10575   7.5619      15.0  7.640227   1.059490      2383.0  3.375354     33.65
# 8116    3.9792      45.0  5.457778   1.100000      1300.0  2.888889     33.80
# 6033    3.8438      28.0  5.422432   1.120545      3502.0  3.670860     34.08
#
#        Longitude
# ...

# %%
y
# Out:
# 11520    5.00001
# 7066     1.69000
# 12346    1.45200
# 10186    1.85200
# 8449     2.31300
#           ...
# 6928     1.50900
# 2815     0.63200
# 10575    3.02000
# 8116     2.10200
# 6033     1.30800
# Name: price, Length: 4128, dtype: float64

# %% [markdown]
# #**Train-Test-Split:**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([2.179  , 1.413  , 0.388  , 1.625  , 1.669  , 0.895  , 2.1    ,
#        4.513  , 0.742  , 0.517  , 0.55   , 1.655  , 1.431  , 1.681  ,
#        1.608  , 1.58   , 0.931  , 3.228  , 4.513  , 1.085  , 3.227  ,
#        0.675  , 2.291  , 1.817  , 0.819  , 2.906  , 1.25   , 2.545  ,
#        1.656  , 1.702  , 3.106  , 2.88   , 3.346  , 0.888  , 3.656  ,
#        0.514  , 0.568  , 2.438  , 3.795  , 0.934  , 0.902  , 2.042  ,
#        2.545  , 2.513  , 5.00001, 2.143  , 1.748  , 1.516  , 4.43   ,
#        3.019  , 1.201  , 1.763  , 1.438  , 1.682  , 3.493  , 1.406  ,
#        1.105  , 2.667  , 0.529  , 1.247  , 3.226  , 3.307  , 0.962  ,
#        0.659  , 1.848  , 5.00001, 1.783  , 0.872  , 1.583  , 2.091  ,
#        1.417  , 1.845  , 2.891  , 1.573  , 1.867  , 0.654  , 2.33   ,
#        2.564  , 4.333  , 1.597  , 1.097  , 2.64   , 3.929  , 1.398  ,
#        3.91   , 1.271  , 1.705  , 1.741  , 1.485  , 0.981  , 1.597  ,
# ...

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5236080617267963

# %% [markdown]
# ###**Hyper-Parameter Tuning:**

# %%
Params = {
    'criterion':['squared_error', 'absolute_error', 'friedman_mse'],
    'splitter':['best', 'random'],
    'max_depth':[1,2,3,4,10],
    'max_features':['auto', 'sqrt', 'log2']
}

# %%
regressor = DecisionTreeRegressor()

# %%
from sklearn.model_selection import GridSearchCV

# %%
GS = GridSearchCV(regressor, Params, cv=3, scoring='neg_mean_squared_error',verbose=3)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
final_model = DecisionTreeRegressor(criterion='absolute_error', max_depth=10, max_features='log2', splitter='best')

# %%
final_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='absolute_error', max_depth=10,
#                       max_features='log2')

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(20,20))
plot_tree(final_model, filled=True)
plt.show()

# %%
y_pred = final_model.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4931874740717084

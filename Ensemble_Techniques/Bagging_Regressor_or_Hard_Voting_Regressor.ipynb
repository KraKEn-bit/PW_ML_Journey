# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
X, y = make_regression(n_samples=1000, n_features=10, noise = 0.1, random_state=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((800, 10), (200, 10), (800,), (200,))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
lr = LinearRegression()
dtr = DecisionTreeRegressor()
svr = SVR(kernel = "linear")

# %% [markdown]
# #**Ensembling**:

# %%
from sklearn.ensemble import VotingRegressor
ensemble_regressor = VotingRegressor(estimators=[("lr", lr), ("dtr", dtr), ("SVR", svr)])
ensemble_regressor
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()),
#                             ('dtr', DecisionTreeRegressor()),
#                             ('SVR', SVR(kernel='linear'))])

# %%
ensemble_regressor.fit(X_train, y_train)
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()),
#                             ('dtr', DecisionTreeRegressor()),
#                             ('SVR', SVR(kernel='linear'))])

# %%
y_pred = ensemble_regressor.predict(X_test)

# %%
y_pred
# Out:
# array([  49.94225635,   40.84457857,  -81.54412856,  -41.09712046,
#         503.07435753,  325.50344599,   45.5226995 ,  -54.52450392,
#         -94.04829307,  -66.20891468, -100.76669527,   48.29758272,
#         -74.46848343, -143.26542553, -311.55125961, -142.52704681,
#        -272.85089546, -161.11443749,  -29.35579152, -188.7015632 ,
#         -47.63050775, -139.13258858,  302.53249562, -155.07788943,
#          81.43984705,  191.73203423,  264.50578396,   58.05584608,
#         -66.68161414,  111.46977232,   71.57114458,  225.48840884,
#         133.77866601,  273.59571139,  121.53350892,  114.2469868 ,
#          62.79038637, -370.52124758, -184.14777544,  -83.05983246,
#          -4.90009787, -100.667716  ,  108.20962995, -129.89131047,
#          82.36148825,   30.15684664,  185.41636073, -125.05876281,
#         162.76042005, -300.48967015,  225.48351948,  364.42615339,
#        -235.77008679,   68.35536838,  -41.10263276,  121.25482668,
#         184.32945339,   86.87200653,   39.56063747,   78.94406464,
#          63.47018548, -427.85410469,  411.92005627,  126.84028095,
#          21.64731939, -171.72289606,  -69.05480307,    2.84538883,
#         -68.33857787,  155.62717906,  464.83715014,   54.60997512,
#         -30.79144557,  -75.01820412,  155.47217983, -155.01440432,
#         -52.88845444,   40.45413599,   33.57285165,    9.65085909,
#         -94.99963411,  164.67863507,  -74.70557176,   69.20497072,
#        -134.10891564,  181.396909  ,   44.36762875, -112.48844982,
#          19.69651588,  -96.76875167, -223.09678849, -227.28850722,
#         -34.887469  ,  164.44393586,  141.88872106,   41.86166368,
#         341.19264995,  -93.84858945,  107.65781793, -118.23875814,
#        -128.9522666 ,  210.59622711,  117.66536467,  -15.39557902,
#        -269.15438771,  159.57195011,   -9.38435865,  -74.5509121 ,
#          23.2185083 ,   64.88496779, -182.84223667,  -79.07824222,
#        -152.87587564,  -24.06367463,  408.92375788,   18.91499162,
#        -155.79184834,   70.48644564, -181.3922919 , -168.84489617,
#        -135.69949752,  181.18857224, -123.21045057,  187.09982591,
#        -182.77736005,  110.26389893, -355.88190147,  -83.74877475,
#         214.59366005, -145.08190691,   14.25733168,   84.02423216,
#          90.14705393, -302.34699391,  -40.22807631,   27.02924267,
#         102.74123257, -198.15897418,   88.29617175,  127.24178059,
#          92.51864326,  199.12016869,  381.14752162,  207.64961712,
#        -103.81816147, -161.59906194,  186.62026884,   71.43629802,
#          79.70131368,  188.54904201,  282.43717021,  177.9201629 ,
#          -0.87335534,  -98.93874057,  -66.09183522,  156.40669637,
#          27.60236753,   66.0794465 , -120.10370785, -335.93058046,
#         348.18068899,  -38.49321212, -351.10372396, -112.2319276 ,
#         -71.92127983, -138.19890608,  -25.67716711,  -76.48715324,
#        -189.67472953,  115.12022541, -209.13425844,  -11.56991966,
#         -92.84799017,   18.59318821,  -85.19014644, -115.41136942,
#         -89.53583317,  125.66533675,  -33.34044559,  -44.6732423 ,
#          -3.45906731,  290.82517927,  175.87200209,   10.00506631,
#          15.48899867, -173.98394469,   29.16125192,  -22.55336727,
#         206.68126961, -161.00682179,  230.37886604,   38.87300985,
#         132.37015788,    8.27445659,   41.81339612,   48.62174263,
#          22.69377501,  321.1953478 , -158.53666585,  -98.29960271])

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9523510105928908
